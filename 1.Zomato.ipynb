# %%
# 1. Importing required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import  plotly.io as pio

pio.renderers.default = 'notebook'

# %%
# 2. Importing the dataset

# %%
raw_df = pd.read_csv("Zomato_Mumbai_Dataset.csv")

# %%
raw_df.head()
# Out:
#              NAME PRICE CUSINE_CATEGORY    CITY                REGION  \
# 0         Hitchki  1200   Modern Indian     NaN                   NaN
# 1    Baba Falooda   400        Desserts     NaN                   NaN
# 2   Chin Chin Chu  1800           Asian     NaN                   NaN
# 3  Butterfly High  1000   Modern Indian  Mumbai  Bandra Kurla Complex
# 4       BKC  DIVE  1200    North Indian     NaN                   NaN
#
#                                                  URL PAGE NO CUSINE TYPE  \
# 0                                                NaN     NaN         NaN
# 1                                                NaN     NaN         NaN
# 2                                                NaN     NaN         NaN
# 3  https://www.zomato.com/mumbai/butterfly-high-b...       1         Bar
# 4                                                NaN     NaN         NaN
#
#                      TIMING RATING_TYPE RATING VOTES Unnamed: 12
# 0                       NaN         NaN    NaN   NaN         NaN
# 1                       NaN         NaN    NaN   NaN         NaN
# 2                       NaN         NaN    NaN   NaN         NaN
# 3  12noon to 130am(Mon-Sun)   Very Good    4.3  1200         NaN
# 4                       NaN         NaN    NaN   NaN         NaN

# %%
# 3. Getting Basic Information about the Dataset

# %%
raw_df.shape
# Out:
# (15081, 13)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15081 entries, 0 to 15080
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             15081 non-null  object
#  1   PRICE            15080 non-null  object
#  2   CUSINE_CATEGORY  15079 non-null  object
#  3   CITY             4711 non-null   object
#  4   REGION           4711 non-null   object
#  5   URL              4710 non-null   object
#  6   PAGE NO          4710 non-null   object
#  7   CUSINE TYPE      4710 non-null   object
#  8   TIMING           4691 non-null   object
#  9   RATING_TYPE      3400 non-null   object
#  10  RATING           3711 non-null   object
#  11  VOTES            3711 non-null   object
#  12  Unnamed: 12      3 non-null      object
# dtypes: object(13)
# memory usage: 1.5+ MB

# %%
raw_df.describe()
# Out:
#          NAME  PRICE CUSINE_CATEGORY    CITY  REGION   URL  PAGE NO  \
# count   15081  15080           15079    4711    4711  4710     4710
# unique  12720     68              84       3     168  3675      905
# top      NAME    400    North Indian  Mumbai  REGION   URL  PAGE NO
# freq      942   2042            3890    3768     942   942      942
#
#         CUSINE TYPE  TIMING RATING_TYPE  RATING  VOTES  \
# count          4710    4691        3400    3711   3711
# unique           19     640          11      30    275
# top     Quick Bites  TIMING     Average  RATING  VOTES
# freq           1815     942        1008     942    942
#
#                              Unnamed: 12
# count                                  3
# unique                                 3
# top     630pm to ..."|"Good"|"3.9"|"369"
# freq                                   1

# %%
# 4. Cleaning the Dataset
# a. Removing the redundant rows of data

# %%
# Checking redundant rows of data

wrong_data = raw_df["PAGE NO"] == 'PAGE NO'
raw_df[wrong_data]
# Out:
#        NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE  \
# 15     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 31     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 47     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 63     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 79     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# ...     ...    ...              ...   ...     ...  ...      ...          ...
# 15000  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15016  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15032  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15048  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15064  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
#
#        TIMING  RATING_TYPE  RATING  VOTES Unnamed: 12
# 15     TIMING  RATING_TYPE  RATING  VOTES         NaN
# 31     TIMING  RATING_TYPE  RATING  VOTES         NaN
# 47     TIMING  RATING_TYPE  RATING  VOTES         NaN
# 63     TIMING  RATING_TYPE  RATING  VOTES         NaN
# 79     TIMING  RATING_TYPE  RATING  VOTES         NaN
# ...       ...          ...     ...    ...         ...
# 15000  TIMING  RATING_TYPE  RATING  VOTES         NaN
# 15016  TIMING  RATING_TYPE  RATING  VOTES         NaN
# 15032  TIMING  RATING_TYPE  RATING  VOTES         NaN
# 15048  TIMING  RATING_TYPE  RATING  VOTES         NaN
# 15064  TIMING  RATING_TYPE  RATING  VOTES         NaN
#
# [942 rows x 13 columns]

# %%
# Performing the Negation of the wrong dataset and storing the correct data back in the raw_data dataframe
# This permenently removes the wrong data from the original dataframe

raw_df = raw_df[~wrong_data]

# %%
# Dropping column which are not required for further analysis

raw_df.drop(['URL', 'PAGE NO', 'CITY'], axis = 1, inplace = True)

# %%
raw_df.head()
# Out:
#              NAME PRICE CUSINE_CATEGORY                REGION CUSINE TYPE  \
# 0         Hitchki  1200   Modern Indian                   NaN         NaN
# 1    Baba Falooda   400        Desserts                   NaN         NaN
# 2   Chin Chin Chu  1800           Asian                   NaN         NaN
# 3  Butterfly High  1000   Modern Indian  Bandra Kurla Complex         Bar
# 4       BKC  DIVE  1200    North Indian                   NaN         NaN
#
#                      TIMING RATING_TYPE RATING VOTES Unnamed: 12
# 0                       NaN         NaN    NaN   NaN         NaN
# 1                       NaN         NaN    NaN   NaN         NaN
# 2                       NaN         NaN    NaN   NaN         NaN
# 3  12noon to 130am(Mon-Sun)   Very Good    4.3  1200         NaN
# 4                       NaN         NaN    NaN   NaN         NaN

# %%
# b. Removing the Null Records

# %%
# Checking for null records

raw_df.isna().sum()
# Out:
# NAME                   0
# PRICE                  1
# CUSINE_CATEGORY        2
# REGION             10370
# CUSINE TYPE        10371
# TIMING             10390
# RATING_TYPE        11681
# RATING             11370
# VOTES              11370
# Unnamed: 12        14136
# dtype: int64

# %%
# Checking for null row

raw_df[raw_df['PRICE'].isnull()]
# Out:
#       NAME PRICE CUSINE_CATEGORY REGION CUSINE TYPE TIMING RATING_TYPE RATING  \
# 15080       NaN             NaN    NaN         NaN    NaN         NaN    NaN
#
#       VOTES Unnamed: 12
# 15080   NaN         NaN

# %%
# Dropping the above row from the dataset

raw_df = raw_df.drop(labels = 15080, axis = 0)

# %%
# Replacing the other null record with NA

raw_df.fillna('NA', inplace = True)
# Confirming all null records are corrected

raw_df.isna().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# Unnamed: 12        0
# dtype: int64

# %%
# c. Converting the DataTypes of the numerical column to numerical datatype

# %%
# Checking for the text values in the columns before converting it to numeric datatype

raw_df['RATING'].value_counts()
# Out:
# RATING
# NA         11369
# -            797
# NEW          296
# 3.1          194
# 3.2          185
# 3.3          182
# 3.4          172
# 3.5          149
# 3.6          148
# 3            138
# 3.8           90
# 3.7           89
# 2.9           68
# 3.9           59
# 4             41
# 2.8           34
# 4.1           27
# 2.7           24
# 4.2           16
# Opening       15
# 2.6            9
# 4.4            8
# 4.3            6
# 4.6            6
# 2.4            6
# 2.5            3
# 2.3            2
# 4.5            2
# 4.7            2
# 2.2            1
# Name: count, dtype: int64

# %%
# Replacing the text values with 0

raw_df['RATING'].replace(to_replace = ['-', 'NEW', 'Opening'], value = 0, inplace = True)

# %%
# Checking for the text values in the columns before converting to the numeric datatype

raw_df['VOTES'].value_counts()
# Out:
# VOTES
# NA      11369
# -         797
# NEW       296
# 4         104
# 6          90
#         ...
# 1200        1
# 129         1
# 332         1
# 351         1
# 914         1
# Name: count, Length: 275, dtype: int64

# %%
# Replacing the text value with '0'

raw_df['VOTES'].replace(to_replace = ['-', 'NEW', 'Opening'], value = 0, inplace = True)
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_7284\3420219496.py:3: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
# Changing datatype of numeric columns

raw_df['PRICE'] = raw_df["PRICE"].astype('int64')
raw_df['RATING'] = raw_df["RATING"].astype('float64')
raw_df['VOTES'] = raw_df["VOTES"].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 # Changing datatype of numeric columns
# ----> 3 raw_df['PRICE'] = raw_df["PRICE"].astype('int64')
#       4 raw_df['RATING'] = raw_df["RATING"].astype('float64')
#       5 raw_df['VOTES'] = raw_df["VOTES"].astype('int64')
#
# File ~\Anaconda3\envs\DSAIML\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\Anaconda3\envs\DSAIML\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~\Anaconda3\envs\DSAIML\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\Anaconda3\envs\DSAIML\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~\Anaconda3\envs\DSAIML\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\Anaconda3\envs\DSAIML\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\Anaconda3\envs\DSAIML\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: ' Mexican '

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14138 entries, 0 to 15079
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             14138 non-null  object
#  1   PRICE            14138 non-null  object
#  2   CUSINE_CATEGORY  14138 non-null  object
#  3   REGION           14138 non-null  object
#  4   CUSINE TYPE      14138 non-null  object
#  5   TIMING           14138 non-null  object
#  6   RATING_TYPE      14138 non-null  object
#  7   RATING           14138 non-null  object
#  8   VOTES            14138 non-null  object
#  9   Unnamed: 12      14138 non-null  object
# dtypes: object(10)
# memory usage: 1.2+ MB

# %%
# d. Working with 'Timing' column

# %%
# Splitting the column and storing it in temp_df dataframe

temp_df =  raw_df['TIMING'].str.split("(", n = 1, expand = True)
temp_df
# Out:
#                      0         1
# 0                   NA      None
# 1                   NA      None
# 2                   NA      None
# 3      12noon to 130am  Mon-Sun)
# 4                   NA      None
# ...                ...       ...
# 15075               NA      None
# 15076               NA      None
# 15077               NA      None
# 15078               NA      None
# 15079               NA      None
#
# [14138 rows x 2 columns]

# %%
# Assigning the values back to raw_data dataframe

raw_df['TIMING'] = temp_df[0]
raw_df['DAYS_OPEN'] = temp_df[1]
raw_df.head()
# Out:
#              NAME PRICE CUSINE_CATEGORY                REGION CUSINE TYPE  \
# 0         Hitchki  1200   Modern Indian                    NA          NA
# 1    Baba Falooda   400        Desserts                    NA          NA
# 2   Chin Chin Chu  1800           Asian                    NA          NA
# 3  Butterfly High  1000   Modern Indian  Bandra Kurla Complex         Bar
# 4       BKC  DIVE  1200    North Indian                    NA          NA
#
#             TIMING RATING_TYPE RATING VOTES Unnamed: 12 DAYS_OPEN
# 0               NA          NA     NA    NA          NA      None
# 1               NA          NA     NA    NA          NA      None
# 2               NA          NA     NA    NA          NA      None
# 3  12noon to 130am   Very Good    4.3  1200          NA  Mon-Sun)
# 4               NA          NA     NA    NA          NA      None

# %%
# Removing the bracket column from the Days_Open Column

raw_df['DAYS_OPEN'] = raw_df['DAYS_OPEN'].str.replace(')', '', regex = True)
raw_df.head()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[32], line 3
#       1 # Removing the bracket column from the Days_Open Column
# ----> 3 raw_df['DAYS_OPEN'] = raw_df['DAYS_OPEN'].str.replace(')', '', regex = True)
#       4 raw_df.head()
#
# File ~\Anaconda3\envs\DSAIML\Lib\site-packages\pandas\core\strings\accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# File ~\Anaconda3\envs\DSAIML\Lib\site-packages\pandas\core\strings\accessor.py:1567, in StringMethods.replace(self, pat, repl, n, case, flags, regex)
#    1564 if case is None:
#    1565     case = True
# -> 1567 result = self._data.array._str_replace(
#    1568     pat, repl, n=n, case=case, flags=flags, regex=regex
#    1569 )
#    1570 return self._wrap_result(result)
#
# File ~\Anaconda3\envs\DSAIML\Lib\site-packages\pandas\core\strings\object_array.py:172, in ObjectStringArrayMixin._str_replace(self, pat, repl, n, case, flags, regex)
#     170     if regex is False:
#     171         pat = re.escape(pat)
# --> 172     pat = re.compile(pat, flags=flags)
#     174 n = n if n >= 0 else 0
#     175 f = lambda x: pat.sub(repl=repl, string=x, count=n)
#
# File ~\Anaconda3\envs\DSAIML\Lib\re\__init__.py:227, in compile(pattern, flags)
#     225 def compile(pattern, flags=0):
#     226     "Compile a regular expression pattern, returning a Pattern object."
# --> 227     return _compile(pattern, flags)
#
# File ~\Anaconda3\envs\DSAIML\Lib\re\__init__.py:294, in _compile(pattern, flags)
#     288     import warnings
#     289     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     290               "as it is an undocumented flag "
#     291               "without an obvious purpose. "
#     292               "Don't use it.",
#     293               DeprecationWarning)
# --> 294 p = _compiler.compile(pattern, flags)
#     295 if not (flags & DEBUG):
#     296     if len(_cache) >= _MAXCACHE:
#     297         # Drop the oldest item
#
# File ~\Anaconda3\envs\DSAIML\Lib\re\_compiler.py:743, in compile(p, flags)
#     741 if isstring(p):
#     742     pattern = p
# --> 743     p = _parser.parse(p, flags)
#     744 else:
#     745     pattern = None
#
# File ~\Anaconda3\envs\DSAIML\Lib\re\_parser.py:987, in parse(str, flags, state)
#     985 if source.next is not None:
#     986     assert source.next == ")"
# --> 987     raise source.error("unbalanced parenthesis")
#     989 for g in p.state.grouprefpos:
#     990     if g >= p.state.groups:
#
# error: unbalanced parenthesis at position 0
